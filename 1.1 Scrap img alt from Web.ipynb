# %%
pip install selenium
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from selenium import webdriver
from selenium.webdriver.support.ui import Select
from time import sleep
from bs4 import BeautifulSoup

# %%
driver = webdriver.Chrome()
driver.get("https://accessguide.hk/index.php?option=com_content&view=article&id=220&Itemid=1054&lang=tc")
sleep(1)

inputElement = driver.find_element_by_name("district")
inputElement.send_keys("中西區")
sleep(1)
inputElement.submit()

soup = BeautifulSoup(driver.page_source, 'lxml')
for div in soup.find_all('div'):
    for img in div.find_all('img', alt=True):
        print(img['alt'])

driver.quit()
# Out:
# The Hong Kong Society for Rehabiliation.
#
#
# Image of 香港海事博物館
# Facilities accessible to wheelchair users but not up to local design standard
# Facilities accessible to wheelchair users but not up to local design standard
# Facilities accessible to wheelchair users and meeting local design standard
# Facilities accessible to wheelchair users but not up to local design standard
# Locked
# Image of 海富中心
# Facilities accessible to wheelchair users but not up to local design standard
# Image of 香港醫學博物館
# Facilities accessible to wheelchair users but not up to local design standard
# Image of 香港大學美術博物館
# Facilities inaccessible to wheelchair users
# Image of 文武廟
# Facilities inaccessible to wheelchair users
# Facilities inaccessible to wheelchair users
# Facilities inaccessible to wheelchair users
# Image of 利源東街
# Facilities accessible to wheelchair users but not up to local design standard
# Image of 利源西街
# Facilities accessible to wheelchair users but not up to local design standard
# ...

# %%
driver = webdriver.Chrome()
driver.get("https://accessguide.hk/index.php?option=com_content&view=article&id=220&Itemid=1054&lang=tc")
sleep(1)

inputElement = driver.find_element_by_name("district")
inputElement.send_keys("東區")
sleep(1)
inputElement.submit()

soup = BeautifulSoup(driver.page_source, 'lxml')
for div in soup.find_all('div'):
    for img in div.find_all('img', alt=True):
        print(img['alt'])

driver.quit()
# Out:
# The Hong Kong Society for Rehabiliation.
#
#
# Image of 香港海防博物館
# Facilities accessible to wheelchair users but not up to local design standard
# Facilities accessible to wheelchair users but not up to local design standard
# Facilities accessible to wheelchair users and meeting local design standard
# Facilities available for visually impaired persons
# Image of 太古城中心
# Facilities accessible to wheelchair users and meeting local design standard
# Facilities accessible to wheelchair users but not up to local design standard
# Facilities accessible to wheelchair users and meeting local design standard
# Facilities accessible to wheelchair users and meeting local design standard
# Facilities available for hearing impaired persons
# Facilities available for visually impaired persons
# Facilities accessible to wheelchair users and meeting local design standard
# Car park with reserved parking space for disabled drivers
# Image of 羅屋民俗館
# Facilities inaccessible to wheelchair users
# ...

# %%
driver = webdriver.Chrome()
driver.get("https://accessguide.hk/index.php?option=com_content&view=article&id=220&Itemid=1054&lang=tc")
sleep(1)

inputElement = driver.find_element_by_name("district")
inputElement.send_keys("離島區")
sleep(1)
inputElement.submit()

soup = BeautifulSoup(driver.page_source, 'lxml')
for div in soup.find_all('div'):
    for img in div.find_all('img', alt=True):
        print(img['alt'])

driver.quit()
# Out:
# The Hong Kong Society for Rehabiliation.
#
#
# Image of 翔天廊
# Facilities accessible to wheelchair users and meeting local design standard
# Facilities accessible to wheelchair users and meeting local design standard
# Facilities available for hearing impaired persons
# Facilities available for visually impaired persons
# Facilities accessible to wheelchair users and meeting local design standard
# Facilities accessible to wheelchair users and meeting local design standard
# Car park with reserved parking space for disabled drivers
# Image of 迪士尼好萊塢酒店
# Facilities inaccessible to wheelchair users
# Facilities available for hearing impaired persons
# Facilities available for visually impaired persons
# Facilities accessible to wheelchair users and meeting local design standard
# Facilities available for hearing impaired persons
# Facilities available for visually impaired persons
# Facilities accessible to wheelchair users and meeting local design standard
# ...

# %%
driver = webdriver.Chrome()
driver.get("https://accessguide.hk/index.php?option=com_content&view=article&id=220&Itemid=1054&lang=tc")
sleep(1)

inputElement = driver.find_element_by_name("district")
inputElement.send_keys("九龍城區")
sleep(1)
inputElement.submit()

soup = BeautifulSoup(driver.page_source, 'lxml')
for div in soup.find_all('div'):
    for img in div.find_all('img', alt=True):
        print(img['alt'])

driver.quit()
# Out:
# The Hong Kong Society for Rehabiliation.
#
#
# Image of 海逸酒店
# Facilities accessible to wheelchair users but not up to local design standard
# Facilities accessible to wheelchair users and meeting local design standard
# Facilities available for visually impaired persons
# Facilities accessible to wheelchair users but not up to local design standard
# Facilities available for hearing impaired persons
# Facilities accessible to wheelchair users but not up to local design standard
# Facilities accessible to wheelchair users and meeting local design standard
# Facilities accessible to wheelchair users but not up to local design standard
# Car park with reserved parking space for disabled drivers
# Image of 九龍維景酒店
# Facilities accessible to wheelchair users but not up to local design standard
# Facilities accessible to wheelchair users but not up to local design standard
# Facilities available for hearing impaired persons
# ...

# %%
driver = webdriver.Chrome()
driver.get("https://accessguide.hk/index.php?option=com_content&view=article&id=220&Itemid=1054&lang=tc")
sleep(1)

inputElement = driver.find_element_by_name("district")
inputElement.send_keys("葵青區")
sleep(1)
inputElement.submit()

soup = BeautifulSoup(driver.page_source, 'lxml')
for div in soup.find_all('div'):
    for img in div.find_all('img', alt=True):
        print(img['alt'])

driver.quit()
# Out:
# The Hong Kong Society for Rehabiliation.
#
#
# Image of 新都會廣場
# Facilities accessible to wheelchair users but not up to local design standard
# Facilities accessible to wheelchair users and meeting local design standard
# Facilities accessible to wheelchair users and meeting local design standard
# Facilities accessible to wheelchair users but not up to local design standard
# Facilities accessible to wheelchair users but not up to local design standard
# Car park with reserved parking space for disabled drivers
# Image of 葵青劇院
# Image of 青衣城
# Facilities accessible to wheelchair users and meeting local design standard
# Facilities accessible to wheelchair users but not up to local design standard
# Facilities accessible to wheelchair users and meeting local design standard
# Facilities available for visually impaired persons
# Facilities accessible to wheelchair users and meeting local design standard
# Facilities accessible to wheelchair users but not up to local design standard
# ...

# %%
driver = webdriver.Chrome()
driver.get("https://accessguide.hk/index.php?option=com_content&view=article&id=220&Itemid=1054&lang=tc")
sleep(1)

inputElement = driver.find_element_by_name("district")
inputElement.send_keys("觀塘區")
sleep(1)
inputElement.submit()

soup = BeautifulSoup(driver.page_source, 'lxml')
for div in soup.find_all('div'):
    for img in div.find_all('img', alt=True):
        print(img['alt'])

driver.quit()
# Out:
# The Hong Kong Society for Rehabiliation.
#
#
# Image of APM
# Facilities accessible to wheelchair users and meeting local design standard
# Facilities accessible to wheelchair users but not up to local design standard
# Facilities accessible to wheelchair users and meeting local design standard
# Facilities accessible to wheelchair users and meeting local design standard
# Facilities available for visually impaired persons
# Facilities accessible to wheelchair users but not up to local design standard
# Car park with reserved parking space for disabled drivers
# Image of 鯉魚門
# Image of 麗港城商場
# Image of APM
# Facilities accessible to wheelchair users and meeting local design standard
# Facilities available for hearing impaired persons
# Facilities available for visually impaired persons
# Facilities accessible to wheelchair users and meeting local design standard
# Facilities accessible to wheelchair users and meeting local design standard
# ...

# %%
driver = webdriver.Chrome()
driver.get("https://accessguide.hk/index.php?option=com_content&view=article&id=220&Itemid=1054&lang=tc")
sleep(1)

inputElement = driver.find_element_by_name("district")
inputElement.send_keys("北區")
sleep(1)
inputElement.submit()

soup = BeautifulSoup(driver.page_source, 'lxml')
for div in soup.find_all('div'):
    for img in div.find_all('img', alt=True):
        print(img['alt'])

driver.quit()
# Out:
# The Hong Kong Society for Rehabiliation.
#
#
# 香港復康會The Hong Kong Society for Rehabilitation
# Esri China (Hong Kong) Limited
# Level Double-A conformance, W3C WAI Web Content Accessibility Guidelines 2.0
# The Hong Kong Society for Rehabiliation.
#
#
# 香港復康會The Hong Kong Society for Rehabilitation
# Esri China (Hong Kong) Limited
# Level Double-A conformance, W3C WAI Web Content Accessibility Guidelines 2.0
# The Hong Kong Society for Rehabiliation.
#
#
# 香港復康會The Hong Kong Society for Rehabilitation
# Esri China (Hong Kong) Limited
# Level Double-A conformance, W3C WAI Web Content Accessibility Guidelines 2.0
# The Hong Kong Society for Rehabiliation.
#
#
# 香港復康會The Hong Kong Society for Rehabilitation
# Esri China (Hong Kong) Limited
# Level Double-A conformance, W3C WAI Web Content Accessibility Guidelines 2.0
# The Hong Kong Society for Rehabiliation.
# The Hong Kong Society for Rehabiliation.
# The Hong Kong Society for Rehabiliation.
# The Hong Kong Society for Rehabiliation.
# ...

# %%
driver = webdriver.Chrome()
driver.get("https://accessguide.hk/index.php?option=com_content&view=article&id=220&Itemid=1054&lang=tc")
sleep(1)

inputElement = driver.find_element_by_name("district")
inputElement.send_keys("西貢區")
sleep(1)
inputElement.submit()

soup = BeautifulSoup(driver.page_source, 'lxml')
for div in soup.find_all('div'):
    for img in div.find_all('img', alt=True):
        print(img['alt'])

driver.quit()
# Out:
# The Hong Kong Society for Rehabiliation.
#
#
# Image of 新都城II期
# Facilities accessible to wheelchair users but not up to local design standard
# Facilities accessible to wheelchair users and meeting local design standard
# Facilities accessible to wheelchair users and meeting local design standard
# Facilities available for hearing impaired persons
# Facilities available for visually impaired persons
# Facilities accessible to wheelchair users but not up to local design standard
# Car park with reserved parking space for disabled drivers
# Image of 上窰民俗文物館
# Facilities inaccessible to wheelchair users
# Facilities accessible to wheelchair users and meeting local design standard
# Facilities inaccessible to wheelchair users
# Image of 西貢海濱
# Facilities accessible to wheelchair users and meeting local design standard
# Facilities accessible to wheelchair users but not up to local design standard
# Parking facilities available
# Image of 東港城
# ...

# %%
driver = webdriver.Chrome()
driver.get("https://accessguide.hk/index.php?option=com_content&view=article&id=220&Itemid=1054&lang=tc")
sleep(1)

inputElement = driver.find_element_by_name("district")
inputElement.send_keys("沙田區")
sleep(1)
inputElement.submit()

soup = BeautifulSoup(driver.page_source, 'lxml')
for div in soup.find_all('div'):
    for img in div.find_all('img', alt=True):
        print(img['alt'])

driver.quit()
# Out:
# The Hong Kong Society for Rehabiliation.
#
#
# Image of 新城市廣場
# Facilities accessible to wheelchair users and meeting local design standard
# Facilities accessible to wheelchair users and meeting local design standard
# Facilities accessible to wheelchair users and meeting local design standard
# Facilities accessible to wheelchair users and meeting local design standard
# Facilities available for hearing impaired persons
# Facilities available for visually impaired persons
# Facilities accessible to wheelchair users and meeting local design standard
# Facilities accessible to wheelchair users and meeting local design standard
# Car park with reserved parking space for disabled drivers
# Image of 沙田大會堂
# Facilities accessible to wheelchair users and meeting local design standard
# Facilities accessible to wheelchair users and meeting local design standard
# Facilities accessible to wheelchair users but not up to local design standard
# ...

# %%
driver = webdriver.Chrome()
driver.get("https://accessguide.hk/index.php?option=com_content&view=article&id=220&Itemid=1054&lang=tc")
sleep(1)

inputElement = driver.find_element_by_name("district")
inputElement.send_keys("深水埗區")
sleep(1)
inputElement.submit()

soup = BeautifulSoup(driver.page_source, 'lxml')
for div in soup.find_all('div'):
    for img in div.find_all('img', alt=True):
        print(img['alt'])

driver.quit()
# Out:
# The Hong Kong Society for Rehabiliation.
#
#
# Image of 西九龍中心
# Facilities accessible to wheelchair users but not up to local design standard
# Facilities accessible to wheelchair users and meeting local design standard
# Facilities accessible to wheelchair users and meeting local design standard
# Facilities available for hearing impaired persons
# Facilities available for visually impaired persons
# Locked
# Parking facilities available
# Image of 又一城
# Facilities accessible to wheelchair users and meeting local design standard
# Facilities accessible to wheelchair users but not up to local design standard
# Facilities accessible to wheelchair users and meeting local design standard
# Facilities accessible to wheelchair users and meeting local design standard
# Facilities available for hearing impaired persons
# Facilities accessible to wheelchair users but not up to local design standard
# Car park with reserved parking space for disabled drivers
# Image of 九龍麗東酒店
# ...

# %%
driver = webdriver.Chrome()
driver.get("https://accessguide.hk/index.php?option=com_content&view=article&id=220&Itemid=1054&lang=tc")
sleep(1)

inputElement = driver.find_element_by_name("district")
inputElement.send_keys("南區")
sleep(1)
inputElement.submit()

soup = BeautifulSoup(driver.page_source, 'lxml')
for div in soup.find_all('div'):
    for img in div.find_all('img', alt=True):
        print(img['alt'])

driver.quit()
# Out:
# The Hong Kong Society for Rehabiliation.
#
#
# Image of (赤柱)天后廟
# Facilities inaccessible to wheelchair users
# Image of 海洋公園
# Facilities accessible to wheelchair users and meeting local design standard
# Facilities available for hearing impaired persons
# Facilities accessible to wheelchair users and meeting local design standard
# Facilities accessible to wheelchair users and meeting local design standard
# Facilities available for hearing impaired persons
# Facilities available for visually impaired persons
# Car park with reserved parking space for disabled drivers
# Facilities accessible to wheelchair users and meeting local design standard
# Facilities available for hearing impaired persons
# Facilities available for visually impaired persons
# Image of 美利樓
# Facilities accessible to wheelchair users and meeting local design standard
# Car park with reserved parking space for disabled drivers
# Image of 赤柱市集
# ...

# %%
driver = webdriver.Chrome()
driver.get("https://accessguide.hk/index.php?option=com_content&view=article&id=220&Itemid=1054&lang=tc")
sleep(1)

inputElement = driver.find_element_by_name("district")
inputElement.send_keys("大埔區")
sleep(1)
inputElement.submit()

soup = BeautifulSoup(driver.page_source, 'lxml')
for div in soup.find_all('div'):
    for img in div.find_all('img', alt=True):
        print(img['alt'])

driver.quit()
# Out:
# The Hong Kong Society for Rehabiliation.
#
#
# Image of 香港鐵路博物館
# Facilities accessible to wheelchair users and meeting local design standard
# Facilities accessible to wheelchair users and meeting local design standard
# Facilities available for visually impaired persons
# Facilities accessible to wheelchair users and meeting local design standard
# Image of 林村許願樹
# Facilities accessible to wheelchair users but not up to local design standard
# Facilities accessible to wheelchair users but not up to local design standard
# Image of 大埔超級城
# Image of 大埔文娛中心
# 香港復康會The Hong Kong Society for Rehabilitation
# Esri China (Hong Kong) Limited
# Level Double-A conformance, W3C WAI Web Content Accessibility Guidelines 2.0
# The Hong Kong Society for Rehabiliation.
#
#
# Image of 香港鐵路博物館
# Facilities accessible to wheelchair users and meeting local design standard
# Facilities accessible to wheelchair users and meeting local design standard
# Facilities available for visually impaired persons
# ...

# %%
driver = webdriver.Chrome()
driver.get("https://accessguide.hk/index.php?option=com_content&view=article&id=220&Itemid=1054&lang=tc")
sleep(1)

inputElement = driver.find_element_by_name("district")
inputElement.send_keys("荃灣區")
sleep(1)
inputElement.submit()

soup = BeautifulSoup(driver.page_source, 'lxml')
for div in soup.find_all('div'):
    for img in div.find_all('img', alt=True):
        print(img['alt'])

driver.quit()
# Out:
# The Hong Kong Society for Rehabiliation.
#
#
# Image of 遠東帝豪酒店
# Facilities accessible to wheelchair users but not up to local design standard
# Facilities accessible to wheelchair users but not up to local design standard
# Facilities available for hearing impaired persons
# Facilities available for visually impaired persons
# Facilities accessible to wheelchair users but not up to local design standard
# Facilities accessible to wheelchair users but not up to local design standard
# Image of 愉景新城
# Facilities accessible to wheelchair users but not up to local design standard
# Facilities accessible to wheelchair users and meeting local design standard
# Facilities accessible to wheelchair users and meeting local design standard
# Facilities available for hearing impaired persons
# Facilities accessible to wheelchair users but not up to local design standard
# Facilities accessible to wheelchair users but not up to local design standard
# ...

# %%
driver = webdriver.Chrome()
driver.get("https://accessguide.hk/index.php?option=com_content&view=article&id=220&Itemid=1054&lang=tc")
sleep(1)

inputElement = driver.find_element_by_name("district")
inputElement.send_keys("屯門區")
sleep(1)
inputElement.submit()

soup = BeautifulSoup(driver.page_source, 'lxml')
for div in soup.find_all('div'):
    for img in div.find_all('img', alt=True):
        print(img['alt'])

driver.quit()
# Out:
# The Hong Kong Society for Rehabiliation.
#
#
# Image of 屯門市廣場
# Facilities accessible to wheelchair users and meeting local design standard
# Facilities accessible to wheelchair users but not up to local design standard
# Facilities accessible to wheelchair users and meeting local design standard
# Facilities accessible to wheelchair users and meeting local design standard
# Facilities available for hearing impaired persons
# Facilities available for visually impaired persons
# Facilities accessible to wheelchair users and meeting local design standard
# Facilities accessible to wheelchair users but not up to local design standard
# Car park with reserved parking space for disabled drivers
# Image of 青松觀
# Facilities accessible to wheelchair users and meeting local design standard
# Facilities accessible to wheelchair users but not up to local design standard
# Facilities accessible to wheelchair users but not up to local design standard
# ...

# %%
driver = webdriver.Chrome()
driver.get("https://accessguide.hk/index.php?option=com_content&view=article&id=220&Itemid=1054&lang=tc")
sleep(1)

inputElement = driver.find_element_by_name("district")
inputElement.send_keys("灣仔區")
sleep(1)
inputElement.submit()

soup = BeautifulSoup(driver.page_source, 'lxml')
for div in soup.find_all('div'):
    for img in div.find_all('img', alt=True):
        print(img['alt'])

driver.quit()
# Out:
# The Hong Kong Society for Rehabiliation.
#
#
# Image of 時代廣場
# Facilities accessible to wheelchair users and meeting local design standard
# Image of 香港賽馬會博物館
# Facilities accessible to wheelchair users and meeting local design standard
# Facilities accessible to wheelchair users but not up to local design standard
# Facilities accessible to wheelchair users and meeting local design standard
# Facilities accessible to wheelchair users and meeting local design standard
# Facilities available for hearing impaired persons
# Facilities accessible to wheelchair users and meeting local design standard
# Facilities accessible to wheelchair users but not up to local design standard
# Parking facilities available
# Image of 時代廣場
# Facilities accessible to wheelchair users and meeting local design standard
# Facilities accessible to wheelchair users and meeting local design standard
# Facilities accessible to wheelchair users and meeting local design standard
# ...

# %%
driver = webdriver.Chrome()
driver.get("https://accessguide.hk/index.php?option=com_content&view=article&id=220&Itemid=1054&lang=tc")
sleep(1)

inputElement = driver.find_element_by_name("district")
inputElement.send_keys("黃大仙區")
sleep(1)
inputElement.submit()

soup = BeautifulSoup(driver.page_source, 'lxml')
for div in soup.find_all('div'):
    for img in div.find_all('img', alt=True):
        print(img['alt'])

driver.quit()
# Out:
# The Hong Kong Society for Rehabiliation.
#
#
# Image of 荷里活廣場
# Facilities accessible to wheelchair users and meeting local design standard
# Facilities accessible to wheelchair users but not up to local design standard
# Facilities accessible to wheelchair users and meeting local design standard
# Facilities accessible to wheelchair users and meeting local design standard
# Facilities available for hearing impaired persons
# Facilities available for visually impaired persons
# Facilities accessible to wheelchair users and meeting local design standard
# Car park with reserved parking space for disabled drivers
# Image of 志蓮淨苑
# Facilities accessible to wheelchair users and meeting local design standard
# Image of 南蓮園池
# Facilities accessible to wheelchair users and meeting local design standard
# Car park with reserved parking space for disabled drivers
# Image of 嗇色園黃大仙祠
# Facilities accessible to wheelchair users and meeting local design standard
# ...

# %%
driver = webdriver.Chrome()
driver.get("https://accessguide.hk/index.php?option=com_content&view=article&id=220&Itemid=1054&lang=tc")
sleep(1)

inputElement = driver.find_element_by_name("district")
inputElement.send_keys("油尖旺區")
sleep(1)
inputElement.submit()

soup = BeautifulSoup(driver.page_source, 'lxml')
for div in soup.find_all('div'):
    for img in div.find_all('img', alt=True):
        print(img['alt'])

driver.quit()
# Out:
# The Hong Kong Society for Rehabiliation.
#
#
# Image of 粵海酒店
# Facilities accessible to wheelchair users but not up to local design standard
# Facilities accessible to wheelchair users and meeting local design standard
# Facilities accessible to wheelchair users but not up to local design standard
# Parking facilities available
# Image of 都會海逸酒店
# Facilities accessible to wheelchair users but not up to local design standard
# Facilities accessible to wheelchair users and meeting local design standard
# Facilities available for visually impaired persons
# Facilities accessible to wheelchair users and meeting local design standard
# Facilities accessible to wheelchair users and meeting local design standard
# Facilities accessible to wheelchair users and meeting local design standard
# Facilities accessible to wheelchair users but not up to local design standard
# Parking facilities available
# Image of 香港日航酒店
# ...

# %%
driver = webdriver.Chrome()
driver.get("https://accessguide.hk/index.php?option=com_content&view=article&id=220&Itemid=1054&lang=tc")
sleep(1)

inputElement = driver.find_element_by_name("district")
inputElement.send_keys("元朗區")
sleep(1)
inputElement.submit()

soup = BeautifulSoup(driver.page_source, 'lxml')
for div in soup.find_all('div'):
    for img in div.find_all('img', alt=True):
        print(img['alt'])

driver.quit()
# Out:
# The Hong Kong Society for Rehabiliation.
#
#
# Image of 嘉湖海逸酒店
# Facilities accessible to wheelchair users but not up to local design standard
# Facilities accessible to wheelchair users and meeting local design standard
# Facilities available for hearing impaired persons
# Facilities accessible to wheelchair users and meeting local design standard
# Facilities accessible to wheelchair users but not up to local design standard
# Facilities accessible to wheelchair users and meeting local design standard
# Parking facilities available
# Image of 屏山鄧族文物館
# Facilities accessible to wheelchair users and meeting local design standard
# Facilities accessible to wheelchair users but not up to local design standard
# Facilities accessible to wheelchair users but not up to local design standard
# Facilities accessible to wheelchair users and meeting local design standard
# Facilities accessible to wheelchair users but not up to local design standard
# Parking facilities available
# ...
